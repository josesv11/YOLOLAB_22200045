# %%
# !pip install -q --upgrade ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

print("Modelo YOLOv8n descargado")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Modelo YOLOv8n descargado

# %%
# !ls -lh /content
# Out:
# total 6.3M
# drwxr-xr-x 1 root root 4.0K Jun  4 13:32 sample_data
# -rw-r--r-- 1 root root 6.3M Jul 22 01:34 yolov8n.pt

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

exported_path = model.export(
    format="litert",
    imgsz=320
)

print("Ruta exportada:", exported_path)
# Out:
# Ultralytics 8.4.104 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 84, 2100) (6.2 MB)
# requirements: Ultralytics requirements ['litert-torch>=0.9.0', 'ai-edge-litert>=2.1.4'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 66 packages in 1.09s
# Prepared 15 packages in 3.77s
# Uninstalled 3 packages in 29ms
# Installed 15 packages in 47ms
#  + ai-edge-litert==2.1.5
#  + ai-edge-quantizer==0.7.0
#  + backports-strenum==1.3.1
#  + fire==0.7.1
#  - immutabledict==4.3.1
#  + immutabledict==4.2.1
#  + jaxtyping==0.3.11
#  + litert-converter==0.2.0
#  + litert-lm-builder==0.14.0
#  + litert-torch==0.9.1
# ...

# %%
import glob
import os

tflite_files = glob.glob(
    "/content/**/*.tflite",
    recursive=True
)

for path in tflite_files:
    size_mb = os.path.getsize(path) / (1024 * 1024)
    print(f"{path} - {size_mb:.2f} MB")
# Out:
# /content/yolov8n.tflite - 12.17 MB

# %%
import glob
import shutil
import os

files = glob.glob(
    "/content/**/*float16*.tflite",
    recursive=True
)

if not files:
    files = glob.glob(
        "/content/**/*.tflite",
        recursive=True
    )

if not files:
    raise FileNotFoundError(
        "No se encontró ningún archivo .tflite"
    )

source_model = files[0]

destination_model = (
    "/content/yolov8n_person_fp16.tflite"
)

shutil.copy(
    source_model,
    destination_model
)

print("Modelo original:", source_model)
print("Modelo final:", destination_model)
print(
    "Tamaño:",
    os.path.getsize(destination_model) / (1024 * 1024),
    "MB"
)
# Out:
# Modelo original: /content/yolov8n.tflite
# Modelo final: /content/yolov8n_person_fp16.tflite
# Tamaño: 12.174260139465332 MB

# %%
# !pip install -q ai-edge-litert

# %%
from ai_edge_litert.interpreter import Interpreter

model_path = "/content/yolov8n_person_fp16.tflite"

interpreter = Interpreter(
    model_path=model_path
)

interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("INPUT:")
for item in input_details:
    print(item)

print("\nOUTPUT:")
for item in output_details:
    print(item)
# Out:
# INPUT:
# {'name': 'serving_default_args_0', 'index': 0, 'shape': array([  1,   3, 320, 320], dtype=int32), 'shape_signature': array([  1,   3, 320, 320], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0, 'block_size': 0}, 'sparsity_parameters': {}}
#
# OUTPUT:
# {'name': 'serving_default_output_0_output', 'index': 414, 'shape': array([   1,   84, 2100], dtype=int32), 'shape_signature': array([   1,   84, 2100], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0, 'block_size': 0}, 'sparsity_parameters': {}}

# %%
print(
    "Input shape:",
    input_details[0]["shape"]
)

print(
    "Input dtype:",
    input_details[0]["dtype"]
)

print(
    "Output shape:",
    output_details[0]["shape"]
)

print(
    "Output dtype:",
    output_details[0]["dtype"]
)
# Out:
# Input shape: [  1   3 320 320]
# Input dtype: <class 'numpy.float32'>
# Output shape: [   1   84 2100]
# Output dtype: <class 'numpy.float32'>

# %%
from google.colab import files

files.download(
    "/content/yolov8n_person_fp16.tflite"
)
